# %% [markdown]
# <a href="https://colab.research.google.com/github/kediwudiko-commits/Keddy/blob/main/Copy_of_EMSC2010_W2_P2_NB2_u8108336.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010_W2_P2_NB2
# ---
#
# *   Class: EMSC2010
# *   Week: 2
# *   Session: Practical 2
#
# ---
#
# From GitHub, you can open this notebook in Google Colab using the 'Open in Colab' button. Then:
#
# 1. Change the notebook name to include your U-number (e.g EMSC2010_W2_P2_NB2_uXXXXXXX.ipynb)
# 2. Save to Google Drive (*File* >>> *Save a copy in Drive*)
# 3. Click *Share* (top right of window)
# 4. Add the **Gmail** addresses of your group and send them a notification
#
# Your group should then open the notebook and:
#
# 5. Write the code for the Fermi estimation problem
#
# The group's edits will still be saved in your Google Drive. Once you can see the edits:
#
# 6. Commit to GitHub (*File* >>> *Save a copy in GitHub*)
# 7. Select the repository for your commit (same as your original repository)
# 8. Give a brief commit message (e.g. 'Commit including Bob's updates')
# 9. Check your GitHub repository, a copy of your notebook should be there.
#
# ---
#
# Because Google Drive is saving your work and the work of your collaborators automatically, you don't need to commit all minor edits to GitHub. Rather commit when you want to archive a version of your notebook because you have completed a substantial task.

# %% [markdown]
# # Group name: Precipitation Pirates
# # Fermi estimation problem: How many water droplets fall in a storm
#
# ### This code was written by Jet, Lee, Binyao and Kedi

# %%
raindrop_size = 0.1 #in ml

# 1ml = 1 cm3
# 1ml = 1000 mm3

raindrop_mm3 = 1000 * raindrop_size

# %%
mm_of_rainfall = 50 #in mm

# %%
area_of_storm = 5 #km^2

# %%
area_in_mm = 5*1000**2 * 100**2 * 10**2 #from km2 to m2 to cm2 to mm2

# %%
volume = area_in_mm*mm_of_rainfall

# %%
raindrops = volume / raindrop_mm3

# %%
print(raindrops)
# Out:
# 2500000000000.0

# %%
print(f"{f"{raindrops:.1e}"} raindrops in a {area_of_storm}km squared storm ")
# Out:
# 2.5e+12raindrops in a 5km squared storm
