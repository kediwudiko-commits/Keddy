# %% [markdown]
# <a href="https://colab.research.google.com/github/kediwudiko-commits/Keddy/blob/main/My_EMSC2010_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random_numbers = np.random.rand(10)
plt.plot(random_numbers)
plt.title('Plot of 10 Random Numbers')
plt.xlabel('Index')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
X = 3
Y = 2

# %%
Z = X + Y #Adding together X and Y
print(Z) #printing Z
# Out:
# 5

# %%
dog = 1
cat = 2
Animals = dog + cat

# %%
Animals
# Out:
# 3

# %%
num_sec_min = 60
num_min_hour = 60
num_hour_day = 24
num_day_year = 365.25

# %%
num_sec_year = num_sec_min * num_min_hour * num_hour_day * num_day_year
print(num_sec_year)
# Out:
# 31557600.0
